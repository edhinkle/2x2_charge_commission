# %%
import sys
import warnings
from datetime import datetime
import numpy as np
import glob
import h5py
from IPython.display import display, clear_output
import yaml
import matplotlib
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.art3d as art3d
from matplotlib.colors import ListedColormap
from mpl_toolkits.axes_grid1.inset_locator import InsetPosition
import os
from matplotlib.backends.backend_pdf import PdfPages

# %%
# Data directory:
#dir = '/global/cfs/cdirs/dune/www/data/2x2/CRS/commission/May2024/self_trigger_m0_test'
#dir = '/global/cfs/cdirs/dune/www/data/2x2/CRS/commission/April2024/self_trigger_test_apr30'
dir1 = '/global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/May2024/self_trigger_m0_test'
dir0 = '/global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/April2024/self_trigger_test_apr30'
ext = 'packet*2024_05_02*5'
h5_files0 = glob.glob(f'{dir0}/{ext}')
h5_files1 = glob.glob(f'{dir1}/{ext}')
h5_files = h5_files0 + h5_files1
#print(h5_files)
print("Number of H5 Files0:", len(h5_files0))
print("Number of H5 Files1:", len(h5_files1))
print("Number of H5 Files:", len(h5_files))
#print(h5_files)
time_only_list = []
for file in h5_files:
    file_name = file.split("/")[-1]
    date = file_name.split("_CDT")[0]
    time_only = date.split("2024_05_02_")[-1]
    time_only_list.append(time_only)
    
# Pair each string with its original position
indexed_time_only = list(enumerate(time_only_list))

# Sort the pairs by string
sorted_pairs = sorted(indexed_time_only, key=lambda pair: pair[1])

# Separate the positions and sorted strings
time_positions, sorted_strings = zip(*sorted_pairs)
print(time_positions)
print(sorted_strings)
# Out:
# Number of H5 Files0: 14
# Number of H5 Files1: 18
# Number of H5 Files: 32
# (10, 1, 3, 6, 9, 4, 0, 12, 5, 13, 2, 11, 8, 7, 19, 20, 14, 18, 25, 22, 24, 16, 15, 28, 29, 27, 26, 17, 30, 23, 31, 21)
# ('11_05_50', '11_09_11', '12_00_12', '12_05_47', '12_10_12', '12_20_20', '12_23_05', '12_26_16', '12_28_16', '12_36_05', '12_36_38', '12_37_09', '12_37_40', '12_38_11', '12_46_05', '12_56_07', '13_06_08', '13_16_09', '13_26_10', '13_36_11', '13_46_12', '13_56_13', '14_06_15', '14_16_16', '14_26_17', '14_36_18', '14_46_19', '14_56_20', '15_06_21', '15_26_41', '15_27_18', '15_32_20')

# %%
with PdfPages('output_full.pdf') as output:
    # Test what's in files
    for i in range(len(h5_files)):
        
        #if i>1: continue
        file_number = time_positions[i]
        file = h5_files[file_number]
        print("------------------------------------")
        print("File:", file)
        f = h5py.File(file,'r')
        print(list(f['packets'].attrs))
        if i==0: 
            print("PACKETS:", f['packets'].dtype.names)
        #print("File keys:", f.keys())
        #print("CONFIGS:", f['configs'].dtype.names)
        #print("Timestamp config:", f['configs']['timestamp'][:])
        #print("IO Group config:", f['configs']['io_group'][:])
        #print("IO Channel config:", f['configs']['io_channel'][:])
        #print("Chip ID config:", f['configs']['chip_id'][:])
        #print("Registers config:", f['configs']['registers'][:])
        #print('MESSAGES:', f['messages'].dtype.names)
        #print("Timestamp message:", f['messages']['timestamp'][:])
        #print("Message message:", f['messages']['message'][:])
        #print("Index message:", f['messages']['index'][:])
        #print("PACKETS:", f['packets'].dtype.names)
        print("Number of packets:", len(f['packets']))
        print("Max Timestamp:", np.max(np.array(f['packets']['timestamp'])))
        print("------------------------------------")
        weird_dw = np.where(np.array(f['packets']['dataword']) == 128)
        datawords = f['packets']['dataword'][weird_dw]
        timestamps = f['packets']['timestamp'][weird_dw]
        chip_ids = f['packets']['chip_id'][weird_dw]
        packet_type = f['packets']['packet_type'][weird_dw]
        print("Number of Packets with Dataword==128:", len(datawords))
        #print("Timestamps length:", len(timestamps))
        print("Packet types represented:", np.unique(np.array(packet_type)))
        
        output.attach_note("File: "+file+"\nNumber of packets: "+str(len(datawords))+"\nNumber of packets w/ dataword==128: "+str(len(datawords))+"\nTypes of packets w/ dw == 128: "+str(np.unique(np.array(packet_type))))
        #plt.hist2d(timestamps, chip_ids, density=datawords)
        #plt.show()
        
        
        #plt.scatter(timestamps, datawords, color='red', s=1)
        #plt.xlabel('Timestamp')
        #plt.ylabel('Dataword')
        #plt.show()
        
        #plt.scatter(chip_ids, datawords, color='blue', s=1)
        #plt.hist2d(chip_ids, datawords, bins=[np.max(chip_ids), 10])
        #plt.xlabel('Chip ID')
        #plt.ylabel('Dataword')
        #plt.show()
        
        plt.scatter(timestamps, chip_ids, color='green', s=1)
        plt.xlabel('Timestamp')
        plt.ylabel('Chip ID')
        output.savefig()
        plt.close()
    
        
        print("------------------------------------")
        
        #print("Packet types:", np.unique(np.array(packet_type)))
        #plt.hist(packet_type, bins=np.max(np.unique(np.array(packet_type))))
# Out:
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/April2024/self_trigger_test_apr30/packet-0000003-2024_05_02_11_05_50_CDT.hdf5
# []
# PACKETS: ('io_group', 'io_channel', 'chip_id', 'packet_type', 'downstream_marker', 'parity', 'valid_parity', 'channel_id', 'timestamp', 'dataword', 'trigger_type', 'local_fifo', 'shared_fifo', 'register_address', 'register_data', 'direction', 'local_fifo_events', 'shared_fifo_events', 'counter', 'fifo_diagnostics_enabled', 'first_packet', 'receipt_timestamp')
# Number of packets: 6519256
# Max Timestamp: 2147483647
# ------------------------------------
# Number of Packets with Dataword==128: 61108
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/April2024/self_trigger_test_apr30/packet-0000003-2024_05_02_11_09_11_CDT.hdf5
# []
# Number of packets: 281361397
# Max Timestamp: 4294967295
# ------------------------------------
# Number of Packets with Dataword==128: 1777559
# Packet types represented: [0 1 2 3]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/April2024/self_trigger_test_apr30/packet-0000004-2024_05_02_12_00_12_CDT.hdf5
# []
# Number of packets: 5040902
# Max Timestamp: 4294967295
# ------------------------------------
# Number of Packets with Dataword==128: 50126
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/April2024/self_trigger_test_apr30/packet-0000005-2024_05_02_12_05_47_CDT.hdf5
# []
# Number of packets: 396456
# Max Timestamp: 2662640269
# ------------------------------------
# Number of Packets with Dataword==128: 3955
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/April2024/self_trigger_test_apr30/packet-0000006-2024_05_02_12_10_12_CDT.hdf5
# []
# Number of packets: 20871450
# Max Timestamp: 4294967295
# ------------------------------------
# Number of Packets with Dataword==128: 208331
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/April2024/self_trigger_test_apr30/packet-0000008-2024_05_02_12_20_20_CDT.hdf5
# []
# Number of packets: 9111757
# Max Timestamp: 4103935937
# ------------------------------------
# Number of Packets with Dataword==128: 90059
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/April2024/self_trigger_test_apr30/packet-0000009-2024_05_02_12_23_05_CDT.hdf5
# []
# Number of packets: 979329
# Max Timestamp: 3463954923
# ------------------------------------
# Number of Packets with Dataword==128: 9742
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/April2024/self_trigger_test_apr30/packet-0000010-2024_05_02_12_26_16_CDT.hdf5
# []
# Number of packets: 4167544
# Max Timestamp: 3008968644
# ------------------------------------
# Number of Packets with Dataword==128: 41323
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/April2024/self_trigger_test_apr30/packet-0000011-2024_05_02_12_28_16_CDT.hdf5
# []
# Number of packets: 4369157
# Max Timestamp: 4208968645
# ------------------------------------
# Number of Packets with Dataword==128: 43131
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/April2024/self_trigger_test_apr30/packet-0000012-2024_05_02_12_36_05_CDT.h5
# []
# Number of packets: 4162374
# Max Timestamp: 4294967295
# ------------------------------------
# Number of Packets with Dataword==128: 40712
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/April2024/self_trigger_test_apr30/packet-0000012-2024_05_02_12_36_38_CDT.h5
# []
# Number of packets: 4205006
# Max Timestamp: 4082771103
# ------------------------------------
# Number of Packets with Dataword==128: 41001
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/April2024/self_trigger_test_apr30/packet-0000012-2024_05_02_12_37_09_CDT.h5
# []
# Number of packets: 4137080
# Max Timestamp: 4294967295
# ------------------------------------
# Number of Packets with Dataword==128: 40744
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/April2024/self_trigger_test_apr30/packet-0000012-2024_05_02_12_37_40_CDT.h5
# []
# Number of packets: 4131239
# Max Timestamp: 3690723991
# ------------------------------------
# Number of Packets with Dataword==128: 41153
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/April2024/self_trigger_test_apr30/packet-0000012-2024_05_02_12_38_11_CDT.h5
# []
# Number of packets: 3106156
# Max Timestamp: 3890723991
# ------------------------------------
# Number of Packets with Dataword==128: 30064
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/May2024/self_trigger_m0_test/packet-0000014-2024_05_02_12_46_05_CDT.h5
# []
# Number of packets: 82734497
# Max Timestamp: 4294967295
# ------------------------------------
# Number of Packets with Dataword==128: 812846
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/May2024/self_trigger_m0_test/packet-0000014-2024_05_02_12_56_07_CDT.h5
# []
# Number of packets: 83367478
# Max Timestamp: 4294967295
# ------------------------------------
# Number of Packets with Dataword==128: 806852
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/May2024/self_trigger_m0_test/packet-0000014-2024_05_02_13_06_08_CDT.h5
# []
# Number of packets: 83259053
# Max Timestamp: 4294967295
# ------------------------------------
# Number of Packets with Dataword==128: 805504
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/May2024/self_trigger_m0_test/packet-0000014-2024_05_02_13_16_09_CDT.h5
# []
# Number of packets: 82455700
# Max Timestamp: 4294967295
# ------------------------------------
# Number of Packets with Dataword==128: 806254
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/May2024/self_trigger_m0_test/packet-0000014-2024_05_02_13_26_10_CDT.h5
# []
# Number of packets: 83718629
# Max Timestamp: 4294967295
# ------------------------------------
# Number of Packets with Dataword==128: 802183
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/May2024/self_trigger_m0_test/packet-0000014-2024_05_02_13_36_11_CDT.h5
# []
# Number of packets: 82985520
# Max Timestamp: 4294967295
# ------------------------------------
# Number of Packets with Dataword==128: 795322
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/May2024/self_trigger_m0_test/packet-0000014-2024_05_02_13_46_12_CDT.h5
# []
# Number of packets: 82890834
# Max Timestamp: 4294967295
# ------------------------------------
# Number of Packets with Dataword==128: 795123
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/May2024/self_trigger_m0_test/packet-0000014-2024_05_02_13_56_13_CDT.h5
# []
# Number of packets: 82785682
# Max Timestamp: 4294967295
# ------------------------------------
# Number of Packets with Dataword==128: 789621
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/May2024/self_trigger_m0_test/packet-0000014-2024_05_02_14_06_15_CDT.h5
# []
# Number of packets: 83346265
# Max Timestamp: 4294967295
# ------------------------------------
# Number of Packets with Dataword==128: 782394
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/May2024/self_trigger_m0_test/packet-0000014-2024_05_02_14_16_16_CDT.h5
# []
# Number of packets: 84093665
# Max Timestamp: 4294967295
# ------------------------------------
# Number of Packets with Dataword==128: 774697
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/May2024/self_trigger_m0_test/packet-0000014-2024_05_02_14_26_17_CDT.h5
# []
# Number of packets: 83275811
# Max Timestamp: 4294967295
# ------------------------------------
# Number of Packets with Dataword==128: 773782
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/May2024/self_trigger_m0_test/packet-0000014-2024_05_02_14_36_18_CDT.h5
# []
# Number of packets: 84163887
# Max Timestamp: 4294967295
# ------------------------------------
# Number of Packets with Dataword==128: 769427
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/May2024/self_trigger_m0_test/packet-0000014-2024_05_02_14_46_19_CDT.h5
# []
# Number of packets: 82115810
# Max Timestamp: 4294967295
# ------------------------------------
# Number of Packets with Dataword==128: 773592
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/May2024/self_trigger_m0_test/packet-0000014-2024_05_02_14_56_20_CDT.h5
# []
# Number of packets: 82187756
# Max Timestamp: 4294967295
# ------------------------------------
# Number of Packets with Dataword==128: 768674
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/May2024/self_trigger_m0_test/packet-0000014-2024_05_02_15_06_21_CDT.h5
# []
# Number of packets: 66612600
# Max Timestamp: 4294967295
# ------------------------------------
# Number of Packets with Dataword==128: 611251
# Packet types represented: [0]
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/May2024/self_trigger_m0_test/packet-2024_05_02_15_26_41_CDT.h5
# []
# Number of packets: 526025
# Max Timestamp: 4129746608
# ------------------------------------
# Number of Packets with Dataword==128: 0
# Packet types represented: []
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/May2024/self_trigger_m0_test/packet-pedestal_m0-2024_05_02_15_27_18_CDT.h5
# []
# Number of packets: 10946738
# Max Timestamp: 4294967295
# ------------------------------------
# Number of Packets with Dataword==128: 0
# Packet types represented: []
# ------------------------------------
# ------------------------------------
# File: /global/cfs/cdirs/dune/www/data/2x2/nearline/packet/commission/May2024/self_trigger_m0_test/packet-pedestal_m0-2024_05_02_15_32_20_CDT.h5
# []
# Number of packets: 10929634
# Max Timestamp: 4294967295
# ------------------------------------
# Number of Packets with Dataword==128: 0
# Packet types represented: []
# ------------------------------------
